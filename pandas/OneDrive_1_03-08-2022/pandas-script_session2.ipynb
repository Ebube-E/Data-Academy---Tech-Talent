# %% [markdown]
# ### Pandas Session 2

# %%
#Data importation:
import pandas as pd
dataframe= pd.read_csv("datacensus2.csv")
dataframe
# Out:
#    Unnamed: 0         Country  Population  Unemployed Persons
# 0           0  United Kingdom    68521968             1704000
# 1           1          France    65273511             2967000
# 2           2          Mexico   128932753             2150582
# 3           3          Canada    37742154             1100000
# 4           4            Peru    32971854              511000

# %%
import pandas as pd

# %%
dataframe= pd.read_csv("datacensus2.csv")
dataframe
# Out:
#    Unnamed: 0         Country  Population  Unemployed Persons
# 0           0  United Kingdom    68521968             1704000
# 1           1          France    65273511             2967000
# 2           2          Mexico   128932753             2150582
# 3           3          Canada    37742154             1100000
# 4           4            Peru    32971854              511000

# %%
dataframe['Unemployed Persons'].sum()
# Out:
# 8432582

# %%
dataframe['Unemployed Persons'].mean()
# Out:
# 1686516.4

# %%
##Create a new column while calculating a ratio:
ratio= dataframe['Unemployed Persons']/dataframe['Population']
ratio_percentage=ratio*100
ratio_percentage
# Out:
# 0    2.486794
# 1    4.545489
# 2    1.667987
# 3    2.914513
# 4    1.549807
# dtype: float64

# %%
dataframe
# Out:
#    Unnamed: 0         Country  Population  Unemployed Persons
# 0           0  United Kingdom    68521968             1704000
# 1           1          France    65273511             2967000
# 2           2          Mexico   128932753             2150582
# 3           3          Canada    37742154             1100000
# 4           4            Peru    32971854              511000

# %%
#Rounding down number to 2 decimals 
ratio_percentage= round(ratio_percentage, 2)
dataframe['Unemployed person %']=ratio_percentage
dataframe
# Out:
#    Unnamed: 0         Country  Population  Unemployed Persons  \
# 0           0  United Kingdom    68521968             1704000
# 1           1          France    65273511             2967000
# 2           2          Mexico   128932753             2150582
# 3           3          Canada    37742154             1100000
# 4           4            Peru    32971854              511000
#
#    Unemployed person %
# 0                 2.49
# 1                 4.55
# 2                 1.67
# 3                 2.91
# 4                 1.55

# %%
#Importing data:
dataframe.to_csv("datacensus3.csv")

# %%
#Data filtering using boolean indexing:
dataframe[dataframe['Population']>100000000]
# Out:
#    Unnamed: 0 Country  Population  Unemployed Persons  Unemployed person %
# 2           2  Mexico   128932753             2150582                 1.67

# %%
#dataframe[ ] will return the true condition in a pandas dataframe
df_mexico= dataframe[dataframe['Population']>100000000]
df_mexico
# Out:
#    Unnamed: 0 Country  Population  Unemployed Persons  Unemployed person %
# 2           2  Mexico   128932753             2150582                 1.67

# %%
#Test 2 conditions:
(dataframe['Country']=="Mexico") & (dataframe['Population']==128932753)
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
#dataframe[ ] will return the true condition in a pandas dataframe
df_mexico= dataframe[(dataframe['Country']=="Mexico") & (dataframe['Population']==128932753)]
df_mexico
# Out:
#    Unnamed: 0 Country  Population  Unemployed Persons  Unemployed person %
# 2           2  Mexico   128932753             2150582                 1.67

# %%
#Import video games dataframe:
dataframe=pd.read_csv("videogames.csv")
dataframe
# Out:
#   score_phrase                 game_title       platform     genre  \
# 0        Great             Critter Crunch         iPhone    Puzzle
# 1        Great                     NHL 13       Xbox 360    Sports
# 2      Amazing    Mario Tennis Power Tour      Game Boy     Sports
# 3        Awful        Double Dragon: Neon  PlayStation 3  Fighting
# 4         Good  Dr. Mario & Puzzle League      Game Boy     Puzzle
# 5         Good    Tekken Tag Tournament 2  PlayStation 3  Fighting
# 6      Amazing               Puzzle Craft         iPhone    Puzzle
#
#    date_released  score
# 0           2008    8.5
# 1           2012    8.5
# 2           2005    9.0
# 3           2012    3.0
# 4           2005    7.8
# 5           2012    7.5
# 6           2012    9.0

# %%
#Grouping data with groupby():
dataframe.groupby("platform")["score"].median()
# Out:
# platform
# Game Boy         8.40
# PlayStation 3    5.25
# Xbox 360         8.50
# iPhone           8.75
# Name: score, dtype: float64

# %%
#function to return a pandas dataframe:
dataframe.groupby("platform",as_index=False)["score"].mean()
# Out:
#         platform  score
# 0      Game Boy    8.40
# 1  PlayStation 3   5.25
# 2       Xbox 360   8.50
# 3         iPhone   8.75

# %%
#Counting unique values in the column genre:
dataframe["genre"].value_counts()
# Out:
# Puzzle      3
# Sports      2
# Fighting    2
# Name: genre, dtype: int64

# %%
pip install seaborn

# %%
#Import the seaborn visualisation library:
import seaborn as sns

# %%
g= sns.barplot(data=dataframe, x='platform', y='score')

# %%
#Import JSON data from an url:
url="http://api.open-notify.org/astros.json"
dataframe = pd.read_json(url)
dataframe
# Out:
#    number                                             people  message
# 0      10          {'name': 'Oleg Artemyev', 'craft': 'ISS'}  success
# 1      10          {'name': 'Denis Matveev', 'craft': 'ISS'}  success
# 2      10        {'name': 'Sergey Korsakov', 'craft': 'ISS'}  success
# 3      10         {'name': 'Kjell Lindgren', 'craft': 'ISS'}  success
# 4      10              {'name': 'Bob Hines', 'craft': 'ISS'}  success
# 5      10  {'name': 'Samantha Cristoforetti', 'craft': 'I...  success
# 6      10        {'name': 'Jessica Watkins', 'craft': 'ISS'}  success
# 7      10         {'name': 'Cai Xuzhe', 'craft': 'Tiangong'}  success
# 8      10         {'name': 'Chen Dong', 'craft': 'Tiangong'}  success
# 9      10          {'name': 'Liu Yang', 'craft': 'Tiangong'}  success

# %%
#We need to flaten the nested JSON data in the column 'people':
normalised_data=pd.json_normalize(dataframe['people'])
normalised_data
# Out:
#                      name     craft
# 0           Oleg Artemyev       ISS
# 1           Denis Matveev       ISS
# 2         Sergey Korsakov       ISS
# 3          Kjell Lindgren       ISS
# 4               Bob Hines       ISS
# 5  Samantha Cristoforetti       ISS
# 6         Jessica Watkins       ISS
# 7               Cai Xuzhe  Tiangong
# 8               Chen Dong  Tiangong
# 9                Liu Yang  Tiangong

# %%
#We need to combine the previous dataframe with the new flatten JSON data:
concat_data= pd.concat([dataframe, normalised_data], axis=1).drop('people', axis=1)
concat_data
# Out:
#    number  message                    name     craft
# 0      10  success           Oleg Artemyev       ISS
# 1      10  success           Denis Matveev       ISS
# 2      10  success         Sergey Korsakov       ISS
# 3      10  success          Kjell Lindgren       ISS
# 4      10  success               Bob Hines       ISS
# 5      10  success  Samantha Cristoforetti       ISS
# 6      10  success         Jessica Watkins       ISS
# 7      10  success               Cai Xuzhe  Tiangong
# 8      10  success               Chen Dong  Tiangong
# 9      10  success                Liu Yang  Tiangong

# %%
pip install requests
# Out:
# Collecting requests
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.8/62.8 kB 1.1 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.6.15-py3-none-any.whl (160 kB)
#      -------------------------------------- 160.2/160.2 kB 3.3 MB/s eta 0:00:00
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.11-py2.py3-none-any.whl (139 kB)
#      -------------------------------------- 139.9/139.9 kB 2.1 MB/s eta 0:00:00
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.0-py3-none-any.whl (39 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
#      ---------------------------------------- 61.2/61.2 kB 1.6 MB/s eta 0:00:00
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2022.6.15 charset-normalizer-2.1.0 idna-3.3 requests-2.28.1 urllib3-1.26.11
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script normalizer.exe is installed in 'C:\Users\GeorginaStanley\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
#Import data from an API:
import requests

# %%
url="https://disease.sh/v3/covid-19/countries"
url
# Out:
# 'https://disease.sh/v3/covid-19/countries'

# %%
url="https://disease.sh/v3/covid-19/countries"
API_requests= requests.get(url)
API_requests
# Out:
# <Response [200]>

# %%
#Import json module:
import json
#Get the request into text and change it to JSON format:
data_API= API_requests.text
json_data=json.loads(data_API)
json_data
# Out:
# [{'updated': 1659534616093,
#   'country': 'Afghanistan',
#   'countryInfo': {'_id': 4,
#    'iso2': 'AF',
#    'iso3': 'AFG',
#    'lat': 33,
#    'long': 65,
#    'flag': 'https://disease.sh/assets/img/flags/af.png'},
#   'cases': 186393,
#   'todayCases': 237,
#   'deaths': 7752,
#   'todayDeaths': 0,
#   'recovered': 167032,
#   'todayRecovered': 104,
#   'active': 11609,
#   'critical': 1124,
#   'casesPerOneMillion': 4574,
#   'deathsPerOneMillion': 190,
#   'tests': 1032620,
#   'testsPerOneMillion': 25339,
#   'population': 40752734,
#   'continent': 'Asia',
#   'oneCasePerPeople': 219,
#   'oneDeathPerPeople': 5257,
#   'oneTestPerPeople': 39,
#   'activePerOneMillion': 284.86,
#   'recoveredPerOneMillion': 4098.67,
#   'criticalPerOneMillion': 27.58},
#  {'updated': 1659534616080,
#   'country': 'Albania',
#   'countryInfo': {'_id': 8,
#    'iso2': 'AL',
#    'iso3': 'ALB',
#    'lat': 41,
#    'long': 20,
#    'flag': 'https://disease.sh/assets/img/flags/al.png'},
#   'cases': 313582,
#   'todayCases': 0,
#   'deaths': 3550,
#   'todayDeaths': 0,
#   'recovered': 299568,
#   'todayRecovered': 0,
#   'active': 10464,
#   'critical': 0,
#   'casesPerOneMillion': 109214,
#   'deathsPerOneMillion': 1236,
#   'tests': 1869495,
#   'testsPerOneMillion': 651106,
#   'population': 2871261,
#   'continent': 'Europe',
#   'oneCasePerPeople': 9,
#   'oneDeathPerPeople': 809,
#   'oneTestPerPeople': 2,
#   'activePerOneMillion': 3644.39,
#   'recoveredPerOneMillion': 104333.25,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534616081,
#   'country': 'Algeria',
#   'countryInfo': {'_id': 12,
#    'iso2': 'DZ',
#    'iso3': 'DZA',
#    'lat': 28,
#    'long': 3,
#    'flag': 'https://disease.sh/assets/img/flags/dz.png'},
#   'cases': 267657,
#   'todayCases': 0,
#   'deaths': 6876,
#   'todayDeaths': 0,
#   'recovered': 179611,
#   'todayRecovered': 0,
#   'active': 81170,
#   'critical': 6,
#   'casesPerOneMillion': 5883,
#   'deathsPerOneMillion': 151,
#   'tests': 230861,
#   'testsPerOneMillion': 5074,
#   'population': 45498823,
#   'continent': 'Africa',
#   'oneCasePerPeople': 170,
#   'oneDeathPerPeople': 6617,
#   'oneTestPerPeople': 197,
#   'activePerOneMillion': 1784,
#   'recoveredPerOneMillion': 3947.6,
#   'criticalPerOneMillion': 0.13},
#  {'updated': 1659534616265,
#   'country': 'Andorra',
#   'countryInfo': {'_id': 20,
#    'iso2': 'AD',
#    'iso3': 'AND',
#    'lat': 42.5,
#    'long': 1.6,
#    'flag': 'https://disease.sh/assets/img/flags/ad.png'},
#   'cases': 45508,
#   'todayCases': 0,
#   'deaths': 153,
#   'todayDeaths': 0,
#   'recovered': 43802,
#   'todayRecovered': 0,
#   'active': 1553,
#   'critical': 14,
#   'casesPerOneMillion': 587033,
#   'deathsPerOneMillion': 1974,
#   'tests': 249838,
#   'testsPerOneMillion': 3222801,
#   'population': 77522,
#   'continent': 'Europe',
#   'oneCasePerPeople': 2,
#   'oneDeathPerPeople': 507,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 20033.02,
#   'recoveredPerOneMillion': 565026.7,
#   'criticalPerOneMillion': 180.59},
#  {'updated': 1659534616165,
#   'country': 'Angola',
#   'countryInfo': {'_id': 24,
#    'iso2': 'AO',
#    'iso3': 'AGO',
#    'lat': -12.5,
#    'long': 18.5,
#    'flag': 'https://disease.sh/assets/img/flags/ao.png'},
#   'cases': 102301,
#   'todayCases': 0,
#   'deaths': 1912,
#   'todayDeaths': 0,
#   'recovered': 97149,
#   'todayRecovered': 0,
#   'active': 3240,
#   'critical': 0,
#   'casesPerOneMillion': 2923,
#   'deathsPerOneMillion': 55,
#   'tests': 1499795,
#   'testsPerOneMillion': 42859,
#   'population': 34993794,
#   'continent': 'Africa',
#   'oneCasePerPeople': 342,
#   'oneDeathPerPeople': 18302,
#   'oneTestPerPeople': 23,
#   'activePerOneMillion': 92.59,
#   'recoveredPerOneMillion': 2776.18,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534616466,
#   'country': 'Anguilla',
#   'countryInfo': {'_id': 660,
#    'iso2': 'AI',
#    'iso3': 'AIA',
#    'lat': 18.25,
#    'long': -63.1667,
#    'flag': 'https://disease.sh/assets/img/flags/ai.png'},
#   'cases': 3580,
#   'todayCases': 0,
#   'deaths': 10,
#   'todayDeaths': 0,
#   'recovered': 3545,
#   'todayRecovered': 0,
#   'active': 25,
#   'critical': 4,
#   'casesPerOneMillion': 234263,
#   'deathsPerOneMillion': 654,
#   'tests': 51382,
#   'testsPerOneMillion': 3362256,
#   'population': 15282,
#   'continent': 'North America',
#   'oneCasePerPeople': 4,
#   'oneDeathPerPeople': 1528,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 1635.91,
#   'recoveredPerOneMillion': 231972.25,
#   'criticalPerOneMillion': 261.75},
#  {'updated': 1659534616393,
#   'country': 'Antigua and Barbuda',
#   'countryInfo': {'_id': 28,
#    'iso2': 'AG',
#    'iso3': 'ATG',
#    'lat': 17.05,
#    'long': -61.8,
#    'flag': 'https://disease.sh/assets/img/flags/ag.png'},
#   'cases': 8773,
#   'todayCases': 0,
#   'deaths': 144,
#   'todayDeaths': 0,
#   'recovered': 8597,
#   'todayRecovered': 0,
#   'active': 32,
#   'critical': 1,
#   'casesPerOneMillion': 88068,
#   'deathsPerOneMillion': 1446,
#   'tests': 18901,
#   'testsPerOneMillion': 189739,
#   'population': 99616,
#   'continent': 'North America',
#   'oneCasePerPeople': 11,
#   'oneDeathPerPeople': 692,
#   'oneTestPerPeople': 5,
#   'activePerOneMillion': 321.23,
#   'recoveredPerOneMillion': 86301.4,
#   'criticalPerOneMillion': 10.04},
#  {'updated': 1659534615670,
#   'country': 'Argentina',
#   'countryInfo': {'_id': 32,
#    'iso2': 'AR',
#    'iso3': 'ARG',
#    'lat': -34,
#    'long': -64,
#    'flag': 'https://disease.sh/assets/img/flags/ar.png'},
#   'cases': 9560307,
#   'todayCases': 0,
#   'deaths': 129369,
#   'todayDeaths': 0,
#   'recovered': 9302467,
#   'todayRecovered': 5665,
#   'active': 128471,
#   'critical': 456,
#   'casesPerOneMillion': 207568,
#   'deathsPerOneMillion': 2809,
#   'tests': 35716069,
#   'testsPerOneMillion': 775446,
#   'population': 46058736,
#   'continent': 'South America',
#   'oneCasePerPeople': 5,
#   'oneDeathPerPeople': 356,
#   'oneTestPerPeople': 1,
#   'activePerOneMillion': 2789.29,
#   'recoveredPerOneMillion': 201969.65,
#   'criticalPerOneMillion': 9.9},
#  {'updated': 1659534616073,
#   'country': 'Armenia',
#   'countryInfo': {'_id': 51,
#    'iso2': 'AM',
#    'iso3': 'ARM',
#    'lat': 40,
#    'long': 45,
#    'flag': 'https://disease.sh/assets/img/flags/am.png'},
#   'cases': 426799,
#   'todayCases': 0,
#   'deaths': 8635,
#   'todayDeaths': 0,
#   'recovered': 412661,
#   'todayRecovered': 0,
#   'active': 5503,
#   'critical': 0,
#   'casesPerOneMillion': 143473,
#   'deathsPerOneMillion': 2903,
#   'tests': 3109931,
#   'testsPerOneMillion': 1045438,
#   'population': 2974765,
#   'continent': 'Asia',
#   'oneCasePerPeople': 7,
#   'oneDeathPerPeople': 345,
#   'oneTestPerPeople': 1,
#   'activePerOneMillion': 1849.89,
#   'recoveredPerOneMillion': 138720.54,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534616268,
#   'country': 'Aruba',
#   'countryInfo': {'_id': 533,
#    'iso2': 'AW',
#    'iso3': 'ABW',
#    'lat': 12.5,
#    'long': -69.9667,
#    'flag': 'https://disease.sh/assets/img/flags/aw.png'},
#   'cases': 42217,
#   'todayCases': 0,
#   'deaths': 226,
#   'todayDeaths': 0,
#   'recovered': 41663,
#   'todayRecovered': 0,
#   'active': 328,
#   'critical': 2,
#   'casesPerOneMillion': 391954,
#   'deathsPerOneMillion': 2098,
#   'tests': 177885,
#   'testsPerOneMillion': 1651533,
#   'population': 107709,
#   'continent': 'North America',
#   'oneCasePerPeople': 3,
#   'oneDeathPerPeople': 477,
#   'oneTestPerPeople': 1,
#   'activePerOneMillion': 3045.24,
#   'recoveredPerOneMillion': 386810.76,
#   'criticalPerOneMillion': 18.57},
#  {'updated': 1659534615671,
#   'country': 'Australia',
#   'countryInfo': {'_id': 36,
#    'iso2': 'AU',
#    'iso3': 'AUS',
#    'lat': -27,
#    'long': 133,
#    'flag': 'https://disease.sh/assets/img/flags/au.png'},
#   'cases': 9517112,
#   'todayCases': 40967,
#   'deaths': 12026,
#   'todayDeaths': 65,
#   'recovered': 9129158,
#   'todayRecovered': 0,
#   'active': 375928,
#   'critical': 162,
#   'casesPerOneMillion': 364423,
#   'deathsPerOneMillion': 460,
#   'tests': 76586805,
#   'testsPerOneMillion': 2932613,
#   'population': 26115548,
#   'continent': 'Australia-Oceania',
#   'oneCasePerPeople': 3,
#   'oneDeathPerPeople': 2172,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 14394.8,
#   'recoveredPerOneMillion': 349567.93,
#   'criticalPerOneMillion': 6.2},
#  {'updated': 1659534615682,
#   'country': 'Austria',
#   'countryInfo': {'_id': 40,
#    'iso2': 'AT',
#    'iso3': 'AUT',
#    'lat': 47.3333,
#    'long': 13.3333,
#    'flag': 'https://disease.sh/assets/img/flags/at.png'},
#   'cases': 4763810,
#   'todayCases': 8475,
#   'deaths': 19151,
#   'todayDeaths': 11,
#   'recovered': 4650435,
#   'todayRecovered': 10795,
#   'active': 94224,
#   'critical': 79,
#   'casesPerOneMillion': 522731,
#   'deathsPerOneMillion': 2101,
#   'tests': 193671589,
#   'testsPerOneMillion': 21251493,
#   'population': 9113317,
#   'continent': 'Europe',
#   'oneCasePerPeople': 2,
#   'oneDeathPerPeople': 476,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 10339.16,
#   'recoveredPerOneMillion': 510290.05,
#   'criticalPerOneMillion': 8.67},
#  {'updated': 1659534615970,
#   'country': 'Azerbaijan',
#   'countryInfo': {'_id': 31,
#    'iso2': 'AZ',
#    'iso3': 'AZE',
#    'lat': 40.5,
#    'long': 47.5,
#    'flag': 'https://disease.sh/assets/img/flags/az.png'},
#   'cases': 799471,
#   'todayCases': 0,
#   'deaths': 9752,
#   'todayDeaths': 0,
#   'recovered': 787080,
#   'todayRecovered': 0,
#   'active': 2639,
#   'critical': 0,
#   'casesPerOneMillion': 77398,
#   'deathsPerOneMillion': 944,
#   'tests': 7051505,
#   'testsPerOneMillion': 682668,
#   'population': 10329338,
#   'continent': 'Asia',
#   'oneCasePerPeople': 13,
#   'oneDeathPerPeople': 1059,
#   'oneTestPerPeople': 1,
#   'activePerOneMillion': 255.49,
#   'recoveredPerOneMillion': 76198.49,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534616358,
#   'country': 'Bahamas',
#   'countryInfo': {'_id': 44,
#    'iso2': 'BS',
#    'iso3': 'BHS',
#    'lat': 24.25,
#    'long': -76,
#    'flag': 'https://disease.sh/assets/img/flags/bs.png'},
#   'cases': 36730,
#   'todayCases': 0,
#   'deaths': 822,
#   'todayDeaths': 0,
#   'recovered': 35320,
#   'todayRecovered': 0,
#   'active': 588,
#   'critical': 0,
#   'casesPerOneMillion': 91582,
#   'deathsPerOneMillion': 2050,
#   'tests': 241422,
#   'testsPerOneMillion': 601955,
#   'population': 401063,
#   'continent': 'North America',
#   'oneCasePerPeople': 11,
#   'oneDeathPerPeople': 488,
#   'oneTestPerPeople': 2,
#   'activePerOneMillion': 1466.1,
#   'recoveredPerOneMillion': 88065.96,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534615973,
#   'country': 'Bahrain',
#   'countryInfo': {'_id': 48,
#    'iso2': 'BH',
#    'iso3': 'BHR',
#    'lat': 26,
#    'long': 50.55,
#    'flag': 'https://disease.sh/assets/img/flags/bh.png'},
#   'cases': 660640,
#   'todayCases': 0,
#   'deaths': 1510,
#   'todayDeaths': 0,
#   'recovered': 654757,
#   'todayRecovered': 0,
#   'active': 4373,
#   'critical': 8,
#   'casesPerOneMillion': 362062,
#   'deathsPerOneMillion': 828,
#   'tests': 10177995,
#   'testsPerOneMillion': 5578020,
#   'population': 1824661,
#   'continent': 'Asia',
#   'oneCasePerPeople': 3,
#   'oneDeathPerPeople': 1208,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 2396.61,
#   'recoveredPerOneMillion': 358837.61,
#   'criticalPerOneMillion': 4.38},
#  {'updated': 1659534615777,
#   'country': 'Bangladesh',
#   'countryInfo': {'_id': 50,
#    'iso2': 'BD',
#    'iso3': 'BGD',
#    'lat': 24,
#    'long': 90,
#    'flag': 'https://disease.sh/assets/img/flags/bd.png'},
#   'cases': 2006368,
#   'todayCases': 375,
#   'deaths': 29298,
#   'todayDeaths': 3,
#   'recovered': 1945088,
#   'todayRecovered': 974,
#   'active': 31982,
#   'critical': 1228,
#   'casesPerOneMillion': 11935,
#   'deathsPerOneMillion': 174,
#   'tests': 14625347,
#   'testsPerOneMillion': 87002,
#   'population': 168103522,
#   'continent': 'Asia',
#   'oneCasePerPeople': 84,
#   'oneDeathPerPeople': 5738,
#   'oneTestPerPeople': 11,
#   'activePerOneMillion': 190.25,
#   'recoveredPerOneMillion': 11570.77,
#   'criticalPerOneMillion': 7.31},
#  {'updated': 1659534616166,
#   'country': 'Barbados',
#   'countryInfo': {'_id': 52,
#    'iso2': 'BB',
#    'iso3': 'BRB',
#    'lat': 13.1667,
#    'long': -59.5333,
#    'flag': 'https://disease.sh/assets/img/flags/bb.png'},
#   'cases': 92516,
#   'todayCases': 0,
#   'deaths': 495,
#   'todayDeaths': 0,
#   'recovered': 89259,
#   'todayRecovered': 0,
#   'active': 2762,
#   'critical': 0,
#   'casesPerOneMillion': 321117,
#   'deathsPerOneMillion': 1718,
#   'tests': 729610,
#   'testsPerOneMillion': 2532427,
#   'population': 288107,
#   'continent': 'North America',
#   'oneCasePerPeople': 3,
#   'oneDeathPerPeople': 582,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 9586.72,
#   'recoveredPerOneMillion': 309811.98,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534615870,
#   'country': 'Belarus',
#   'countryInfo': {'_id': 112,
#    'iso2': 'BY',
#    'iso3': 'BLR',
#    'lat': 53,
#    'long': 28,
#    'flag': 'https://disease.sh/assets/img/flags/by.png'},
#   'cases': 994037,
#   'todayCases': 0,
#   'deaths': 7118,
#   'todayDeaths': 0,
#   'recovered': 985592,
#   'todayRecovered': 0,
#   'active': 1327,
#   'critical': 0,
#   'casesPerOneMillion': 105269,
#   'deathsPerOneMillion': 754,
#   'tests': 13646641,
#   'testsPerOneMillion': 1445181,
#   'population': 9442858,
#   'continent': 'Europe',
#   'oneCasePerPeople': 9,
#   'oneDeathPerPeople': 1327,
#   'oneTestPerPeople': 1,
#   'activePerOneMillion': 140.53,
#   'recoveredPerOneMillion': 104374.33,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534615764,
#   'country': 'Belgium',
#   'countryInfo': {'_id': 56,
#    'iso2': 'BE',
#    'iso3': 'BEL',
#    'lat': 50.8333,
#    'long': 4,
#    'flag': 'https://disease.sh/assets/img/flags/be.png'},
#   'cases': 4425201,
#   'todayCases': 0,
#   'deaths': 32263,
#   'todayDeaths': 0,
#   'recovered': 4228227,
#   'todayRecovered': 0,
#   'active': 164711,
#   'critical': 108,
#   'casesPerOneMillion': 378398,
#   'deathsPerOneMillion': 2759,
#   'tests': 35042202,
#   'testsPerOneMillion': 2996453,
#   'population': 11694561,
#   'continent': 'Europe',
#   'oneCasePerPeople': 3,
#   'oneDeathPerPeople': 362,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 14084.41,
#   'recoveredPerOneMillion': 361555,
#   'criticalPerOneMillion': 9.24},
#  {'updated': 1659534616182,
#   'country': 'Belize',
#   'countryInfo': {'_id': 84,
#    'iso2': 'BZ',
#    'iso3': 'BLZ',
#    'lat': 17.25,
#    'long': -88.75,
#    'flag': 'https://disease.sh/assets/img/flags/bz.png'},
#   'cases': 67111,
#   'todayCases': 0,
#   'deaths': 680,
#   'todayDeaths': 0,
#   'recovered': 65978,
#   'todayRecovered': 0,
#   'active': 453,
#   'critical': 6,
#   'casesPerOneMillion': 162635,
#   'deathsPerOneMillion': 1648,
#   'tests': 576016,
#   'testsPerOneMillion': 1395898,
#   'population': 412649,
#   'continent': 'North America',
#   'oneCasePerPeople': 6,
#   'oneDeathPerPeople': 607,
#   'oneTestPerPeople': 1,
#   'activePerOneMillion': 1097.79,
#   'recoveredPerOneMillion': 159888.91,
#   'criticalPerOneMillion': 14.54},
#  {'updated': 1659534616367,
#   'country': 'Benin',
#   'countryInfo': {'_id': 204,
#    'iso2': 'BJ',
#    'iso3': 'BEN',
#    'lat': 9.5,
#    'long': 2.25,
#    'flag': 'https://disease.sh/assets/img/flags/bj.png'},
#   'cases': 27316,
#   'todayCases': 0,
#   'deaths': 163,
#   'todayDeaths': 0,
#   'recovered': 25506,
#   'todayRecovered': 0,
#   'active': 1647,
#   'critical': 5,
#   'casesPerOneMillion': 2137,
#   'deathsPerOneMillion': 13,
#   'tests': 604310,
#   'testsPerOneMillion': 47271,
#   'population': 12783983,
#   'continent': 'Africa',
#   'oneCasePerPeople': 468,
#   'oneDeathPerPeople': 78429,
#   'oneTestPerPeople': 21,
#   'activePerOneMillion': 128.83,
#   'recoveredPerOneMillion': 1995.15,
#   'criticalPerOneMillion': 0.39},
#  {'updated': 1659534616379,
#   'country': 'Bermuda',
#   'countryInfo': {'_id': 60,
#    'iso2': 'BM',
#    'iso3': 'BMU',
#    'lat': 32.3333,
#    'long': -64.75,
#    'flag': 'https://disease.sh/assets/img/flags/bm.png'},
#   'cases': 17193,
#   'todayCases': 0,
#   'deaths': 144,
#   'todayDeaths': 0,
#   'recovered': 16786,
#   'todayRecovered': 0,
#   'active': 263,
#   'critical': 0,
#   'casesPerOneMillion': 278208,
#   'deathsPerOneMillion': 2330,
#   'tests': 966915,
#   'testsPerOneMillion': 15646127,
#   'population': 61799,
#   'continent': 'North America',
#   'oneCasePerPeople': 4,
#   'oneDeathPerPeople': 429,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 4255.73,
#   'recoveredPerOneMillion': 271622.52,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534616259,
#   'country': 'Bhutan',
#   'countryInfo': {'_id': 64,
#    'iso2': 'BT',
#    'iso3': 'BTN',
#    'lat': 27.5,
#    'long': 90.5,
#    'flag': 'https://disease.sh/assets/img/flags/bt.png'},
#   'cases': 60530,
#   'todayCases': 0,
#   'deaths': 21,
#   'todayDeaths': 0,
#   'recovered': 60434,
#   'todayRecovered': 0,
#   'active': 75,
#   'critical': 0,
#   'casesPerOneMillion': 76689,
#   'deathsPerOneMillion': 27,
#   'tests': 2303734,
#   'testsPerOneMillion': 2918750,
#   'population': 789288,
#   'continent': 'Asia',
#   'oneCasePerPeople': 13,
#   'oneDeathPerPeople': 37585,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 95.02,
#   'recoveredPerOneMillion': 76567.74,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534615867,
#   'country': 'Bolivia',
#   'countryInfo': {'_id': 68,
#    'iso2': 'BO',
#    'iso3': 'BOL',
#    'lat': -17,
#    'long': -65,
#    'flag': 'https://disease.sh/assets/img/flags/bo.png'},
#   'cases': 1047198,
#   'todayCases': 5359,
#   'deaths': 22072,
#   'todayDeaths': 3,
#   'recovered': 954848,
#   'todayRecovered': 2906,
#   'active': 70278,
#   'critical': 220,
#   'casesPerOneMillion': 87235,
#   'deathsPerOneMillion': 1839,
#   'tests': 2705422,
#   'testsPerOneMillion': 225370,
#   'population': 12004365,
#   'continent': 'South America',
#   'oneCasePerPeople': 11,
#   'oneDeathPerPeople': 544,
#   'oneTestPerPeople': 4,
#   'activePerOneMillion': 5854.37,
#   'recoveredPerOneMillion': 79541.73,
#   'criticalPerOneMillion': 18.33},
#  {'updated': 1659534616075,
#   'country': 'Bosnia',
#   'countryInfo': {'_id': 70,
#    'iso2': 'BA',
#    'iso3': 'BIH',
#    'lat': 44,
#    'long': 18,
#    'flag': 'https://disease.sh/assets/img/flags/ba.png'},
#   'cases': 386474,
#   'todayCases': 466,
#   'deaths': 15883,
#   'todayDeaths': 15,
#   'recovered': 0,
#   'todayRecovered': 0,
#   'active': 370591,
#   'critical': 0,
#   'casesPerOneMillion': 119342,
#   'deathsPerOneMillion': 4905,
#   'tests': 1817436,
#   'testsPerOneMillion': 561217,
#   'population': 3238386,
#   'continent': 'Europe',
#   'oneCasePerPeople': 8,
#   'oneDeathPerPeople': 204,
#   'oneTestPerPeople': 2,
#   'activePerOneMillion': 114436.94,
#   'recoveredPerOneMillion': 0,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534616079,
#   'country': 'Botswana',
#   'countryInfo': {'_id': 72,
#    'iso2': 'BW',
#    'iso3': 'BWA',
#    'lat': -22,
#    'long': 24,
#    'flag': 'https://disease.sh/assets/img/flags/bw.png'},
#   'cases': 325470,
#   'todayCases': 0,
#   'deaths': 2770,
#   'todayDeaths': 0,
#   'recovered': 322415,
#   'todayRecovered': 0,
#   'active': 285,
#   'critical': 1,
#   'casesPerOneMillion': 132821,
#   'deathsPerOneMillion': 1130,
#   'tests': 2026898,
#   'testsPerOneMillion': 827158,
#   'population': 2450435,
#   'continent': 'Africa',
#   'oneCasePerPeople': 8,
#   'oneDeathPerPeople': 885,
#   'oneTestPerPeople': 1,
#   'activePerOneMillion': 116.31,
#   'recoveredPerOneMillion': 131574.6,
#   'criticalPerOneMillion': 0.41},
#  {'updated': 1659534615575,
#   'country': 'Brazil',
#   'countryInfo': {'_id': 76,
#    'iso2': 'BR',
#    'iso3': 'BRA',
#    'lat': -10,
#    'long': -55,
#    'flag': 'https://disease.sh/assets/img/flags/br.png'},
#   'cases': 33890428,
#   'todayCases': 0,
#   'deaths': 679063,
#   'todayDeaths': 0,
#   'recovered': 32511634,
#   'todayRecovered': 0,
#   'active': 699731,
#   'critical': 8318,
#   'casesPerOneMillion': 157116,
#   'deathsPerOneMillion': 3148,
#   'tests': 63776166,
#   'testsPerOneMillion': 295666,
#   'population': 215703263,
#   'continent': 'South America',
#   'oneCasePerPeople': 6,
#   'oneDeathPerPeople': 318,
#   'oneTestPerPeople': 3,
#   'activePerOneMillion': 3243.95,
#   'recoveredPerOneMillion': 150723.89,
#   'criticalPerOneMillion': 38.56},
#  {'updated': 1659534616458,
#   'country': 'British Virgin Islands',
#   'countryInfo': {'_id': 92,
#    'iso2': 'VG',
#    'iso3': 'VGB',
#    'lat': 18.5,
#    'long': -64.5,
#    'flag': 'https://disease.sh/assets/img/flags/vg.png'},
#   'cases': 7131,
#   'todayCases': 0,
#   'deaths': 63,
#   'todayDeaths': 0,
#   'recovered': 0,
#   'todayRecovered': 0,
#   'active': 7068,
#   'critical': 1,
#   'casesPerOneMillion': 232659,
#   'deathsPerOneMillion': 2055,
#   'tests': 105790,
#   'testsPerOneMillion': 3451550,
#   'population': 30650,
#   'continent': 'North America',
#   'oneCasePerPeople': 4,
#   'oneDeathPerPeople': 487,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 230603.59,
#   'recoveredPerOneMillion': 0,
#   'criticalPerOneMillion': 32.63},
#  {'updated': 1659534616090,
#   'country': 'Brunei',
#   'countryInfo': {'_id': 96,
#    'iso2': 'BN',
#    'iso3': 'BRN',
#    'lat': 4.5,
#    'long': 114.6667,
#    'flag': 'https://disease.sh/assets/img/flags/bn.png'},
#   'cases': 210417,
#   'todayCases': 1020,
#   'deaths': 225,
#   'todayDeaths': 0,
#   'recovered': 205773,
#   'todayRecovered': 0,
#   'active': 4419,
#   'critical': 3,
#   'casesPerOneMillion': 471581,
#   'deathsPerOneMillion': 504,
#   'tests': 717784,
#   'testsPerOneMillion': 1608678,
#   'population': 446195,
#   'continent': 'Asia',
#   'oneCasePerPeople': 2,
#   'oneDeathPerPeople': 1983,
#   'oneTestPerPeople': 1,
#   'activePerOneMillion': 9903.74,
#   'recoveredPerOneMillion': 461172.81,
#   'criticalPerOneMillion': 6.72},
#  {'updated': 1659534615858,
#   'country': 'Bulgaria',
#   'countryInfo': {'_id': 100,
#    'iso2': 'BG',
#    'iso3': 'BGR',
#    'lat': 43,
#    'long': 25,
#    'flag': 'https://disease.sh/assets/img/flags/bg.png'},
#   'cases': 1211728,
#   'todayCases': 0,
#   'deaths': 37414,
#   'todayDeaths': 0,
#   'recovered': 1148341,
#   'todayRecovered': 0,
#   'active': 25973,
#   'critical': 58,
#   'casesPerOneMillion': 177161,
#   'deathsPerOneMillion': 5470,
#   'tests': 10280997,
#   'testsPerOneMillion': 1503137,
#   'population': 6839692,
#   'continent': 'Europe',
#   'oneCasePerPeople': 6,
#   'oneDeathPerPeople': 183,
#   'oneTestPerPeople': 1,
#   'activePerOneMillion': 3797.39,
#   'recoveredPerOneMillion': 167893.67,
#   'criticalPerOneMillion': 8.48},
#  {'updated': 1659534616372,
#   'country': 'Burkina Faso',
#   'countryInfo': {'_id': 854,
#    'iso2': 'BF',
#    'iso3': 'BFA',
#    'lat': 13,
#    'long': -2,
#    'flag': 'https://disease.sh/assets/img/flags/bf.png'},
#   'cases': 21128,
#   'todayCases': 0,
#   'deaths': 387,
#   'todayDeaths': 0,
#   'recovered': 20439,
#   'todayRecovered': 0,
#   'active': 302,
#   'critical': 0,
#   'casesPerOneMillion': 956,
#   'deathsPerOneMillion': 18,
#   'tests': 248995,
#   'testsPerOneMillion': 11269,
#   'population': 22096048,
#   'continent': 'Africa',
#   'oneCasePerPeople': 1046,
#   'oneDeathPerPeople': 57096,
#   'oneTestPerPeople': 89,
#   'activePerOneMillion': 13.67,
#   'recoveredPerOneMillion': 925.01,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534616262,
#   'country': 'Burundi',
#   'countryInfo': {'_id': 108,
#    'iso2': 'BI',
#    'iso3': 'BDI',
#    'lat': -3.5,
#    'long': 30,
#    'flag': 'https://disease.sh/assets/img/flags/bi.png'},
#   'cases': 46151,
#   'todayCases': 0,
#   'deaths': 38,
#   'todayDeaths': 0,
#   'recovered': 0,
#   'todayRecovered': 0,
#   'active': 46113,
#   'critical': 0,
#   'casesPerOneMillion': 3655,
#   'deathsPerOneMillion': 3,
#   'tests': 345742,
#   'testsPerOneMillion': 27380,
#   'population': 12627743,
#   'continent': 'Africa',
#   'oneCasePerPeople': 274,
#   'oneDeathPerPeople': 332309,
#   'oneTestPerPeople': 37,
#   'activePerOneMillion': 3651.72,
#   'recoveredPerOneMillion': 0,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534616258,
#   'country': 'Cabo Verde',
#   'countryInfo': {'_id': 132,
#    'iso2': 'CV',
#    'iso3': 'CPV',
#    'lat': 16,
#    'long': -24,
#    'flag': 'https://disease.sh/assets/img/flags/cv.png'},
#   'cases': 62172,
#   'todayCases': 0,
#   'deaths': 410,
#   'todayDeaths': 0,
#   'recovered': 61642,
#   'todayRecovered': 0,
#   'active': 120,
#   'critical': 23,
#   'casesPerOneMillion': 109351,
#   'deathsPerOneMillion': 721,
#   'tests': 401622,
#   'testsPerOneMillion': 706393,
#   'population': 568553,
#   'continent': 'Africa',
#   'oneCasePerPeople': 9,
#   'oneDeathPerPeople': 1387,
#   'oneTestPerPeople': 1,
#   'activePerOneMillion': 211.06,
#   'recoveredPerOneMillion': 108419.09,
#   'criticalPerOneMillion': 40.45},
#  {'updated': 1659534616161,
#   'country': 'Cambodia',
#   'countryInfo': {'_id': 116,
#    'iso2': 'KH',
#    'iso3': 'KHM',
#    'lat': 13,
#    'long': 105,
#    'flag': 'https://disease.sh/assets/img/flags/kh.png'},
#   'cases': 136908,
#   'todayCases': 40,
#   'deaths': 3056,
#   'todayDeaths': 0,
#   'recovered': 133608,
#   'todayRecovered': 39,
#   'active': 244,
#   'critical': 0,
#   'casesPerOneMillion': 7960,
#   'deathsPerOneMillion': 178,
#   'tests': 3022218,
#   'testsPerOneMillion': 175706,
#   'population': 17200455,
#   'continent': 'Asia',
#   'oneCasePerPeople': 126,
#   'oneDeathPerPeople': 5628,
#   'oneTestPerPeople': 6,
#   'activePerOneMillion': 14.19,
#   'recoveredPerOneMillion': 7767.7,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534616163,
#   'country': 'Cameroon',
#   'countryInfo': {'_id': 120,
#    'iso2': 'CM',
#    'iso3': 'CMR',
#    'lat': 6,
#    'long': 12,
#    'flag': 'https://disease.sh/assets/img/flags/cm.png'},
#   'cases': 120215,
#   'todayCases': 0,
#   'deaths': 1931,
#   'todayDeaths': 0,
#   'recovered': 117791,
#   'todayRecovered': 0,
#   'active': 493,
#   'critical': 13,
#   'casesPerOneMillion': 4306,
#   'deathsPerOneMillion': 69,
#   'tests': 1751774,
#   'testsPerOneMillion': 62741,
#   'population': 27920928,
#   'continent': 'Africa',
#   'oneCasePerPeople': 232,
#   'oneDeathPerPeople': 14459,
#   'oneTestPerPeople': 16,
#   'activePerOneMillion': 17.66,
#   'recoveredPerOneMillion': 4218.74,
#   'criticalPerOneMillion': 0.47},
#  {'updated': 1659534615766,
#   'country': 'Canada',
#   'countryInfo': {'_id': 124,
#    'iso2': 'CA',
#    'iso3': 'CAN',
#    'lat': 60,
#    'long': -95,
#    'flag': 'https://disease.sh/assets/img/flags/ca.png'},
#   'cases': 4056133,
#   'todayCases': 0,
#   'deaths': 42681,
#   'todayDeaths': 0,
#   'recovered': 0,
#   'todayRecovered': 0,
#   'active': 4013452,
#   'critical': 195,
#   'casesPerOneMillion': 105544,
#   'deathsPerOneMillion': 1111,
#   'tests': 62586673,
#   'testsPerOneMillion': 1628559,
#   'population': 38430718,
#   'continent': 'North America',
#   'oneCasePerPeople': 9,
#   'oneDeathPerPeople': 900,
#   'oneTestPerPeople': 1,
#   'activePerOneMillion': 104433.44,
#   'recoveredPerOneMillion': 0,
#   'criticalPerOneMillion': 5.07},
#  {'updated': 1659534616390,
#   'country': 'Caribbean Netherlands',
#   'countryInfo': {'_id': 535,
#    'iso2': 'BQ',
#    'iso3': 'BES',
#    'lat': 12.2,
#    'long': -68.26,
#    'flag': 'https://disease.sh/assets/img/flags/bq.png'},
#   'cases': 10802,
#   'todayCases': 0,
#   'deaths': 35,
#   'todayDeaths': 0,
#   'recovered': 10476,
#   'todayRecovered': 0,
#   'active': 291,
#   'critical': 0,
#   'casesPerOneMillion': 404115,
#   'deathsPerOneMillion': 1309,
#   'tests': 30126,
#   'testsPerOneMillion': 1127048,
#   'population': 26730,
#   'continent': 'North America',
#   'oneCasePerPeople': 2,
#   'oneDeathPerPeople': 764,
#   'oneTestPerPeople': 1,
#   'activePerOneMillion': 10886.64,
#   'recoveredPerOneMillion': 391919.19,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534616365,
#   'country': 'Cayman Islands',
#   'countryInfo': {'_id': 136,
#    'iso2': 'KY',
#    'iso3': 'CYM',
#    'lat': 19.5,
#    'long': -80.5,
#    'flag': 'https://disease.sh/assets/img/flags/ky.png'},
#   'cases': 28784,
#   'todayCases': 0,
#   'deaths': 29,
#   'todayDeaths': 0,
#   'recovered': 8553,
#   'todayRecovered': 0,
#   'active': 20202,
#   'critical': 1,
#   'casesPerOneMillion': 427519,
#   'deathsPerOneMillion': 431,
#   'tests': 222773,
#   'testsPerOneMillion': 3308772,
#   'population': 67328,
#   'continent': 'North America',
#   'oneCasePerPeople': 2,
#   'oneDeathPerPeople': 2322,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 300053.47,
#   'recoveredPerOneMillion': 127034.81,
#   'criticalPerOneMillion': 14.85},
#  {'updated': 1659534616382,
#   'country': 'Central African Republic',
#   'countryInfo': {'_id': 140,
#    'iso2': 'CF',
#    'iso3': 'CAF',
#    'lat': 7,
#    'long': 21,
#    'flag': 'https://disease.sh/assets/img/flags/cf.png'},
#   'cases': 14772,
#   'todayCases': 0,
#   'deaths': 113,
#   'todayDeaths': 0,
#   'recovered': 6859,
#   'todayRecovered': 0,
#   'active': 7800,
#   'critical': 2,
#   'casesPerOneMillion': 2952,
#   'deathsPerOneMillion': 23,
#   'tests': 81294,
#   'testsPerOneMillion': 16244,
#   'population': 5004512,
#   'continent': 'Africa',
#   'oneCasePerPeople': 339,
#   'oneDeathPerPeople': 44288,
#   'oneTestPerPeople': 62,
#   'activePerOneMillion': 1558.59,
#   'recoveredPerOneMillion': 1370.56,
#   'criticalPerOneMillion': 0.4},
#  {'updated': 1659534616457,
#   'country': 'Chad',
#   'countryInfo': {'_id': 148,
#    'iso2': 'TD',
#    'iso3': 'TCD',
#    'lat': 15,
#    'long': 19,
#    'flag': 'https://disease.sh/assets/img/flags/td.png'},
#   'cases': 7437,
#   'todayCases': 0,
#   'deaths': 193,
#   'todayDeaths': 0,
#   'recovered': 4874,
#   'todayRecovered': 0,
#   'active': 2370,
#   'critical': 0,
#   'casesPerOneMillion': 427,
#   'deathsPerOneMillion': 11,
#   'tests': 191341,
#   'testsPerOneMillion': 10992,
#   'population': 17406702,
#   'continent': 'Africa',
#   'oneCasePerPeople': 2341,
#   'oneDeathPerPeople': 90190,
#   'oneTestPerPeople': 91,
#   'activePerOneMillion': 136.15,
#   'recoveredPerOneMillion': 280.01,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534616168,
#   'country': 'Channel Islands',
#   'countryInfo': {'_id': 832,
#    'iso2': 'JE',
#    'iso3': 'JEY',
#    'lat': 49.21,
#    'long': -2.13,
#    'flag': 'https://disease.sh/assets/img/flags/je.png'},
#   'cases': 88201,
#   'todayCases': 0,
#   'deaths': 193,
#   'todayDeaths': 0,
#   'recovered': 87063,
#   'todayRecovered': 0,
#   'active': 945,
#   'critical': 0,
#   'casesPerOneMillion': 497754,
#   'deathsPerOneMillion': 1089,
#   'tests': 1252808,
#   'testsPerOneMillion': 7070102,
#   'population': 177198,
#   'continent': 'Europe',
#   'oneCasePerPeople': 2,
#   'oneDeathPerPeople': 918,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 5333.02,
#   'recoveredPerOneMillion': 491331.73,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534615765,
#   'country': 'Chile',
#   'countryInfo': {'_id': 152,
#    'iso2': 'CL',
#    'iso3': 'CHL',
#    'lat': -30,
#    'long': -71,
#    'flag': 'https://disease.sh/assets/img/flags/cl.png'},
#   'cases': 4253056,
#   'todayCases': 0,
#   'deaths': 59629,
#   'todayDeaths': 0,
#   'recovered': 3964068,
#   'todayRecovered': 0,
#   'active': 229359,
#   'critical': 169,
#   'casesPerOneMillion': 218580,
#   'deathsPerOneMillion': 3065,
#   'tests': 42129154,
#   'testsPerOneMillion': 2165173,
#   'population': 19457638,
#   'continent': 'South America',
#   'oneCasePerPeople': 5,
#   'oneDeathPerPeople': 326,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 11787.61,
#   'recoveredPerOneMillion': 203728.12,
#   'criticalPerOneMillion': 8.69},
#  {'updated': 1659534616480,
#   'country': 'China',
#   'countryInfo': {'_id': 156,
#    'iso2': 'CN',
#    'iso3': 'CHN',
#    'lat': 35,
#    'long': 105,
#    'flag': 'https://disease.sh/assets/img/flags/cn.png'},
#   'cases': 229802,
#   'todayCases': 101,
#   'deaths': 5226,
#   'todayDeaths': 0,
#   'recovered': 223009,
#   'todayRecovered': 128,
#   'active': 1567,
#   'critical': 1,
#   'casesPerOneMillion': 160,
#   'deathsPerOneMillion': 4,
#   'tests': 160000000,
#   'testsPerOneMillion': 111163,
#   'population': 1439323776,
#   'continent': 'Asia',
#   'oneCasePerPeople': 6263,
#   'oneDeathPerPeople': 275416,
#   'oneTestPerPeople': 9,
#   'activePerOneMillion': 1.09,
#   'recoveredPerOneMillion': 154.94,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534615676,
#   'country': 'Colombia',
#   'countryInfo': {'_id': 170,
#    'iso2': 'CO',
#    'iso3': 'COL',
#    'lat': 4,
#    'long': -72,
#    'flag': 'https://disease.sh/assets/img/flags/co.png'},
#   'cases': 6265798,
#   'todayCases': 0,
#   'deaths': 140845,
#   'todayDeaths': 0,
#   'recovered': 6079628,
#   'todayRecovered': 0,
#   'active': 45325,
#   'critical': 342,
#   'casesPerOneMillion': 120470,
#   'deathsPerOneMillion': 2708,
#   'tests': 35992047,
#   'testsPerOneMillion': 692003,
#   'population': 52011425,
#   'continent': 'South America',
#   'oneCasePerPeople': 8,
#   'oneDeathPerPeople': 369,
#   'oneTestPerPeople': 1,
#   'activePerOneMillion': 871.44,
#   'recoveredPerOneMillion': 116890.24,
#   'criticalPerOneMillion': 6.58},
#  {'updated': 1659534616395,
#   'country': 'Comoros',
#   'countryInfo': {'_id': 174,
#    'iso2': 'KM',
#    'iso3': 'COM',
#    'lat': -12.1667,
#    'long': 44.25,
#    'flag': 'https://disease.sh/assets/img/flags/km.png'},
#   'cases': 8329,
#   'todayCases': 0,
#   'deaths': 160,
#   'todayDeaths': 0,
#   'recovered': 7933,
#   'todayRecovered': 0,
#   'active': 236,
#   'critical': 0,
#   'casesPerOneMillion': 9171,
#   'deathsPerOneMillion': 176,
#   'tests': 0,
#   'testsPerOneMillion': 0,
#   'population': 908149,
#   'continent': 'Africa',
#   'oneCasePerPeople': 109,
#   'oneDeathPerPeople': 5676,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 259.87,
#   'recoveredPerOneMillion': 8735.35,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534616370,
#   'country': 'Congo',
#   'countryInfo': {'_id': 178,
#    'iso2': 'CG',
#    'iso3': 'COG',
#    'lat': -1,
#    'long': 15,
#    'flag': 'https://disease.sh/assets/img/flags/cg.png'},
#   'cases': 24775,
#   'todayCases': 0,
#   'deaths': 386,
#   'todayDeaths': 0,
#   'recovered': 20178,
#   'todayRecovered': 0,
#   'active': 4211,
#   'critical': 0,
#   'casesPerOneMillion': 4271,
#   'deathsPerOneMillion': 67,
#   'tests': 347815,
#   'testsPerOneMillion': 59961,
#   'population': 5800725,
#   'continent': 'Africa',
#   'oneCasePerPeople': 234,
#   'oneDeathPerPeople': 15028,
#   'oneTestPerPeople': 17,
#   'activePerOneMillion': 725.94,
#   'recoveredPerOneMillion': 3478.53,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534616462,
#   'country': 'Cook Islands',
#   'countryInfo': {'_id': 184,
#    'iso2': 'CK',
#    'iso3': 'COK',
#    'lat': -21.2333,
#    'long': -159.7667,
#    'flag': 'https://disease.sh/assets/img/flags/ck.png'},
#   'cases': 6109,
#   'todayCases': 0,
#   'deaths': 1,
#   'todayDeaths': 0,
#   'recovered': 5982,
#   'todayRecovered': 0,
#   'active': 126,
#   'critical': 0,
#   'casesPerOneMillion': 347161,
#   'deathsPerOneMillion': 57,
#   'tests': 19690,
#   'testsPerOneMillion': 1118941,
#   'population': 17597,
#   'continent': 'Australia-Oceania',
#   'oneCasePerPeople': 3,
#   'oneDeathPerPeople': 17597,
#   'oneTestPerPeople': 1,
#   'activePerOneMillion': 7160.31,
#   'recoveredPerOneMillion': 339944.31,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534615869,
#   'country': 'Costa Rica',
#   'countryInfo': {'_id': 188,
#    'iso2': 'CR',
#    'iso3': 'CRI',
#    'lat': 10,
#    'long': -84,
#    'flag': 'https://disease.sh/assets/img/flags/cr.png'},
#   'cases': 1005223,
#   'todayCases': 0,
#   'deaths': 8720,
#   'todayDeaths': 0,
#   'recovered': 860711,
#   'todayRecovered': 0,
#   'active': 135792,
#   'critical': 52,
#   'casesPerOneMillion': 193651,
#   'deathsPerOneMillion': 1680,
#   'tests': 4659757,
#   'testsPerOneMillion': 897676,
#   'population': 5190911,
#   'continent': 'North America',
#   'oneCasePerPeople': 5,
#   'oneDeathPerPeople': 595,
#   'oneTestPerPeople': 1,
#   'activePerOneMillion': 26159.57,
#   'recoveredPerOneMillion': 165811.16,
#   'criticalPerOneMillion': 10.02},
#  {'updated': 1659534615859,
#   'country': 'Croatia',
#   'countryInfo': {'_id': 191,
#    'iso2': 'HR',
#    'iso3': 'HRV',
#    'lat': 45.1667,
#    'long': 15.5,
#    'flag': 'https://disease.sh/assets/img/flags/hr.png'},
#   'cases': 1189593,
#   'todayCases': 1768,
#   'deaths': 16350,
#   'todayDeaths': 14,
#   'recovered': 1163697,
#   'todayRecovered': 517,
#   'active': 9546,
#   'critical': 27,
#   'casesPerOneMillion': 293536,
#   'deathsPerOneMillion': 4034,
#   'tests': 5058531,
#   'testsPerOneMillion': 1248211,
#   'population': 4052626,
#   'continent': 'Europe',
#   'oneCasePerPeople': 3,
#   'oneDeathPerPeople': 248,
#   'oneTestPerPeople': 1,
#   'activePerOneMillion': 2355.51,
#   'recoveredPerOneMillion': 287146.41,
#   'criticalPerOneMillion': 6.66},
#  {'updated': 1659534615863,
#   'country': 'Cuba',
#   'countryInfo': {'_id': 192,
#    'iso2': 'CU',
#    'iso3': 'CUB',
#    'lat': 21.5,
#    'long': -80,
#    'flag': 'https://disease.sh/assets/img/flags/cu.png'},
#   'cases': 1108261,
#   'todayCases': 0,
#   'deaths': 8529,
#   'todayDeaths': 0,
#   'recovered': 1099254,
#   'todayRecovered': 0,
#   'active': 478,
#   'critical': 23,
#   'casesPerOneMillion': 97970,
#   'deathsPerOneMillion': 754,
#   'tests': 13997964,
#   'testsPerOneMillion': 1237418,
#   'population': 11312236,
#   'continent': 'North America',
#   'oneCasePerPeople': 10,
#   'oneDeathPerPeople': 1326,
#   'oneTestPerPeople': 1,
#   'activePerOneMillion': 42.26,
#   'recoveredPerOneMillion': 97173.89,
#   'criticalPerOneMillion': 2.03},
#  {'updated': 1659534616266,
#   'country': 'Curaçao',
#   'countryInfo': {'_id': 531,
#    'iso2': 'CW',
#    'iso3': 'CUW',
#    'lat': 12.15,
#    'long': -68.97,
#    'flag': 'https://disease.sh/assets/img/flags/cw.png'},
#   'cases': 45127,
#   'todayCases': 0,
#   'deaths': 282,
#   'todayDeaths': 0,
#   'recovered': 44720,
#   'todayRecovered': 0,
#   'active': 125,
#   'critical': 3,
#   'casesPerOneMillion': 272689,
#   'deathsPerOneMillion': 1704,
#   'tests': 496693,
#   'testsPerOneMillion': 3001366,
#   'population': 165489,
#   'continent': 'North America',
#   'oneCasePerPeople': 4,
#   'oneDeathPerPeople': 587,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 755.34,
#   'recoveredPerOneMillion': 270229.44,
#   'criticalPerOneMillion': 18.13},
#  {'updated': 1659534616066,
#   'country': 'Cyprus',
#   'countryInfo': {'_id': 196,
#    'iso2': 'CY',
#    'iso3': 'CYP',
#    'lat': 35,
#    'long': 33,
#    'flag': 'https://disease.sh/assets/img/flags/cy.png'},
#   'cases': 562911,
#   'todayCases': 0,
#   'deaths': 1115,
#   'todayDeaths': 0,
#   'recovered': 124370,
#   'todayRecovered': 0,
#   'active': 437426,
#   'critical': 60,
#   'casesPerOneMillion': 459277,
#   'deathsPerOneMillion': 910,
#   'tests': 9572310,
#   'testsPerOneMillion': 7810012,
#   'population': 1225646,
#   'continent': 'Asia',
#   'oneCasePerPeople': 2,
#   'oneDeathPerPeople': 1099,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 356894.24,
#   'recoveredPerOneMillion': 101473.02,
#   'criticalPerOneMillion': 48.95},
#  {'updated': 1659534615768,
#   'country': 'Czechia',
#   'countryInfo': {'_id': 203,
#    'iso2': 'CZ',
#    'iso3': 'CZE',
#    'lat': 49.75,
#    'long': 15.5,
#    'flag': 'https://disease.sh/assets/img/flags/cz.png'},
#   'cases': 3991594,
#   'todayCases': 3079,
#   'deaths': 40518,
#   'todayDeaths': 5,
#   'recovered': 3929399,
#   'todayRecovered': 719,
#   'active': 21677,
#   'critical': 31,
#   'casesPerOneMillion': 371300,
#   'deathsPerOneMillion': 3769,
#   'tests': 55771832,
#   'testsPerOneMillion': 5187928,
#   'population': 10750310,
#   'continent': 'Europe',
#   'oneCasePerPeople': 3,
#   'oneDeathPerPeople': 265,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 2016.41,
#   'recoveredPerOneMillion': 365514.95,
#   'criticalPerOneMillion': 2.88},
#  {'updated': 1659534616171,
#   'country': "Côte d'Ivoire",
#   'countryInfo': {'_id': 384,
#    'iso2': 'CI',
#    'iso3': 'CIV',
#    'lat': 8,
#    'long': -5,
#    'flag': 'https://disease.sh/assets/img/flags/ci.png'},
#   'cases': 85444,
#   'todayCases': 0,
#   'deaths': 811,
#   'todayDeaths': 0,
#   'recovered': 84538,
#   'todayRecovered': 0,
#   'active': 95,
#   'critical': 0,
#   'casesPerOneMillion': 3080,
#   'deathsPerOneMillion': 29,
#   'tests': 1582257,
#   'testsPerOneMillion': 57044,
#   'population': 27737554,
#   'continent': 'Africa',
#   'oneCasePerPeople': 325,
#   'oneDeathPerPeople': 34202,
#   'oneTestPerPeople': 18,
#   'activePerOneMillion': 3.42,
#   'recoveredPerOneMillion': 3047.78,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534616167,
#   'country': 'DRC',
#   'countryInfo': {'_id': 180,
#    'iso2': 'CD',
#    'iso3': 'COD',
#    'lat': 0,
#    'long': 25,
#    'flag': 'https://disease.sh/assets/img/flags/cd.png'},
#   'cases': 92173,
#   'todayCases': 0,
#   'deaths': 1390,
#   'todayDeaths': 0,
#   'recovered': 50930,
#   'todayRecovered': 0,
#   'active': 39853,
#   'critical': 0,
#   'casesPerOneMillion': 968,
#   'deathsPerOneMillion': 15,
#   'tests': 846704,
#   'testsPerOneMillion': 8891,
#   'population': 95227577,
#   'continent': 'Africa',
#   'oneCasePerPeople': 1033,
#   'oneDeathPerPeople': 68509,
#   'oneTestPerPeople': 112,
#   'activePerOneMillion': 418.5,
#   'recoveredPerOneMillion': 534.82,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534615773,
#   'country': 'Denmark',
#   'countryInfo': {'_id': 208,
#    'iso2': 'DK',
#    'iso3': 'DNK',
#    'lat': 56,
#    'long': 10,
#    'flag': 'https://disease.sh/assets/img/flags/dk.png'},
#   'cases': 3065856,
#   'todayCases': 1388,
#   'deaths': 6687,
#   'todayDeaths': 5,
#   'recovered': 3041525,
#   'todayRecovered': 1719,
#   'active': 17644,
#   'critical': 17,
#   'casesPerOneMillion': 525458,
#   'deathsPerOneMillion': 1146,
#   'tests': 127995615,
#   'testsPerOneMillion': 21937203,
#   'population': 5834637,
#   'continent': 'Europe',
#   'oneCasePerPeople': 2,
#   'oneDeathPerPeople': 873,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 3024.01,
#   'recoveredPerOneMillion': 521287.79,
#   'criticalPerOneMillion': 2.91},
#  {'updated': 1659534616473,
#   'country': 'Diamond Princess',
#   'countryInfo': {'_id': None,
#    'iso2': None,
#    'iso3': None,
#    'lat': 0,
#    'long': 0,
#    'flag': 'https://disease.sh/assets/img/flags/unknown.png'},
#   'cases': 712,
#   'todayCases': 0,
#   'deaths': 13,
#   'todayDeaths': 0,
#   'recovered': 699,
#   'todayRecovered': 0,
#   'active': 0,
#   'critical': 0,
#   'casesPerOneMillion': 0,
#   'deathsPerOneMillion': 0,
#   'tests': 0,
#   'testsPerOneMillion': 0,
#   'population': 0,
#   'continent': '',
#   'oneCasePerPeople': 0,
#   'oneDeathPerPeople': 0,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 0,
#   'recoveredPerOneMillion': 0,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534616380,
#   'country': 'Djibouti',
#   'countryInfo': {'_id': 262,
#    'iso2': 'DJ',
#    'iso3': 'DJI',
#    'lat': 11.5,
#    'long': 43,
#    'flag': 'https://disease.sh/assets/img/flags/dj.png'},
#   'cases': 15690,
#   'todayCases': 0,
#   'deaths': 189,
#   'todayDeaths': 0,
#   'recovered': 15427,
#   'todayRecovered': 0,
#   'active': 74,
#   'critical': 0,
#   'casesPerOneMillion': 15414,
#   'deathsPerOneMillion': 186,
#   'tests': 305941,
#   'testsPerOneMillion': 300562,
#   'population': 1017898,
#   'continent': 'Africa',
#   'oneCasePerPeople': 65,
#   'oneDeathPerPeople': 5386,
#   'oneTestPerPeople': 3,
#   'activePerOneMillion': 72.7,
#   'recoveredPerOneMillion': 15155.74,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534616382,
#   'country': 'Dominica',
#   'countryInfo': {'_id': 212,
#    'iso2': 'DM',
#    'iso3': 'DMA',
#    'lat': 15.4167,
#    'long': -61.3333,
#    'flag': 'https://disease.sh/assets/img/flags/dm.png'},
#   'cases': 14852,
#   'todayCases': 0,
#   'deaths': 68,
#   'todayDeaths': 0,
#   'recovered': 14554,
#   'todayRecovered': 0,
#   'active': 230,
#   'critical': 0,
#   'casesPerOneMillion': 205257,
#   'deathsPerOneMillion': 940,
#   'tests': 210195,
#   'testsPerOneMillion': 2904931,
#   'population': 72358,
#   'continent': 'North America',
#   'oneCasePerPeople': 5,
#   'oneDeathPerPeople': 1064,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 3178.64,
#   'recoveredPerOneMillion': 201138.78,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534616061,
#   'country': 'Dominican Republic',
#   'countryInfo': {'_id': 214,
#    'iso2': 'DO',
#    'iso3': 'DOM',
#    'lat': 19,
#    'long': -70.6667,
#    'flag': 'https://disease.sh/assets/img/flags/do.png'},
#   'cases': 629643,
#   'todayCases': 0,
#   'deaths': 4383,
#   'todayDeaths': 0,
#   'recovered': 623715,
#   'todayRecovered': 0,
#   'active': 1545,
#   'critical': 17,
#   'casesPerOneMillion': 56856,
#   'deathsPerOneMillion': 396,
#   'tests': 3590929,
#   'testsPerOneMillion': 324259,
#   'population': 11074270,
#   'continent': 'North America',
#   'oneCasePerPeople': 18,
#   'oneDeathPerPeople': 2527,
#   'oneTestPerPeople': 3,
#   'activePerOneMillion': 139.51,
#   'recoveredPerOneMillion': 56321.09,
#   'criticalPerOneMillion': 1.54},
#  {'updated': 1659534615961,
#   'country': 'Ecuador',
#   'countryInfo': {'_id': 218,
#    'iso2': 'EC',
#    'iso3': 'ECU',
#    'lat': -2,
#    'long': -77.5,
#    'flag': 'https://disease.sh/assets/img/flags/ec.png'},
#   'cases': 961345,
#   'todayCases': 0,
#   'deaths': 35801,
#   'todayDeaths': 0,
#   'recovered': 900020,
#   'todayRecovered': 610,
#   'active': 25524,
#   'critical': 759,
#   'casesPerOneMillion': 52820,
#   'deathsPerOneMillion': 1967,
#   'tests': 2470170,
#   'testsPerOneMillion': 135719,
#   'population': 18200555,
#   'continent': 'South America',
#   'oneCasePerPeople': 19,
#   'oneDeathPerPeople': 508,
#   'oneTestPerPeople': 7,
#   'activePerOneMillion': 1402.37,
#   'recoveredPerOneMillion': 49450.14,
#   'criticalPerOneMillion': 41.7},
#  {'updated': 1659534616068,
#   'country': 'Egypt',
#   'countryInfo': {'_id': 818,
#    'iso2': 'EG',
#    'iso3': 'EGY',
#    'lat': 27,
#    'long': 30,
#    'flag': 'https://disease.sh/assets/img/flags/eg.png'},
#   'cases': 515645,
#   'todayCases': 0,
#   'deaths': 24613,
#   'todayDeaths': 0,
#   'recovered': 442182,
#   'todayRecovered': 0,
#   'active': 48850,
#   'critical': 122,
#   'casesPerOneMillion': 4849,
#   'deathsPerOneMillion': 231,
#   'tests': 3693367,
#   'testsPerOneMillion': 34728,
#   'population': 106350908,
#   'continent': 'Africa',
#   'oneCasePerPeople': 206,
#   'oneDeathPerPeople': 4321,
#   'oneTestPerPeople': 29,
#   'activePerOneMillion': 459.33,
#   'recoveredPerOneMillion': 4157.76,
#   'criticalPerOneMillion': 1.15},
#  {'updated': 1659534616092,
#   'country': 'El Salvador',
#   'countryInfo': {'_id': 222,
#    'iso2': 'SV',
#    'iso3': 'SLV',
#    'lat': 13.8333,
#    'long': -88.9167,
#    'flag': 'https://disease.sh/assets/img/flags/sv.png'},
#   'cases': 190818,
#   'todayCases': 0,
#   'deaths': 4201,
#   'todayDeaths': 0,
#   'recovered': 172310,
#   'todayRecovered': 0,
#   'active': 14307,
#   'critical': 8,
#   'casesPerOneMillion': 29113,
#   'deathsPerOneMillion': 641,
#   'tests': 2456913,
#   'testsPerOneMillion': 374855,
#   'population': 6554297,
#   'continent': 'North America',
#   'oneCasePerPeople': 34,
#   'oneDeathPerPeople': 1560,
#   'oneTestPerPeople': 3,
#   'activePerOneMillion': 2182.84,
#   'recoveredPerOneMillion': 26289.62,
#   'criticalPerOneMillion': 1.22},
#  {'updated': 1659534616380,
#   'country': 'Equatorial Guinea',
#   'countryInfo': {'_id': 226,
#    'iso2': 'GQ',
#    'iso3': 'GNQ',
#    'lat': 2,
#    'long': 10,
#    'flag': 'https://disease.sh/assets/img/flags/gq.png'},
#   'cases': 16741,
#   'todayCases': 0,
#   'deaths': 183,
#   'todayDeaths': 0,
#   'recovered': 16459,
#   'todayRecovered': 0,
#   'active': 99,
#   'critical': 5,
#   'casesPerOneMillion': 11169,
#   'deathsPerOneMillion': 122,
#   'tests': 358620,
#   'testsPerOneMillion': 239255,
#   'population': 1498905,
#   'continent': 'Africa',
#   'oneCasePerPeople': 90,
#   'oneDeathPerPeople': 8191,
#   'oneTestPerPeople': 4,
#   'activePerOneMillion': 66.05,
#   'recoveredPerOneMillion': 10980.68,
#   'criticalPerOneMillion': 3.34},
#  {'updated': 1659534616392,
#   'country': 'Eritrea',
#   'countryInfo': {'_id': 232,
#    'iso2': 'ER',
#    'iso3': 'ERI',
#    'lat': 15,
#    'long': 39,
#    'flag': 'https://disease.sh/assets/img/flags/er.png'},
#   'cases': 10074,
#   'todayCases': 0,
#   'deaths': 103,
#   'todayDeaths': 0,
#   'recovered': 9837,
#   'todayRecovered': 0,
#   'active': 134,
#   'critical': 0,
#   'casesPerOneMillion': 2761,
#   'deathsPerOneMillion': 28,
#   'tests': 23693,
#   'testsPerOneMillion': 6494,
#   'population': 3648560,
#   'continent': 'Africa',
#   'oneCasePerPeople': 362,
#   'oneDeathPerPeople': 35423,
#   'oneTestPerPeople': 154,
#   'activePerOneMillion': 36.73,
#   'recoveredPerOneMillion': 2696.13,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534616064,
#   'country': 'Estonia',
#   'countryInfo': {'_id': 233,
#    'iso2': 'EE',
#    'iso3': 'EST',
#    'lat': 59,
#    'long': 26,
#    'flag': 'https://disease.sh/assets/img/flags/ee.png'},
#   'cases': 591058,
#   'todayCases': 0,
#   'deaths': 2628,
#   'todayDeaths': 0,
#   'recovered': 524990,
#   'todayRecovered': 0,
#   'active': 63440,
#   'critical': 4,
#   'casesPerOneMillion': 444943,
#   'deathsPerOneMillion': 1978,
#   'tests': 3468756,
#   'testsPerOneMillion': 2611246,
#   'population': 1328391,
#   'continent': 'Europe',
#   'oneCasePerPeople': 2,
#   'oneDeathPerPeople': 505,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 47757.02,
#   'recoveredPerOneMillion': 395207.44,
#   'criticalPerOneMillion': 3.01},
#  {'updated': 1659534616070,
#   'country': 'Ethiopia',
#   'countryInfo': {'_id': 231,
#    'iso2': 'ET',
#    'iso3': 'ETH',
#    'lat': 8,
#    'long': 38,
#    'flag': 'https://disease.sh/assets/img/flags/et.png'},
#   'cases': 492316,
#   'todayCases': 0,
#   'deaths': 7568,
#   'todayDeaths': 0,
#   'recovered': 469788,
#   'todayRecovered': 0,
#   'active': 14960,
#   'critical': 22,
#   'casesPerOneMillion': 4072,
#   'deathsPerOneMillion': 63,
#   'tests': 5146587,
#   'testsPerOneMillion': 42573,
#   'population': 120889430,
#   'continent': 'Africa',
#   'oneCasePerPeople': 246,
#   'oneDeathPerPeople': 15974,
#   'oneTestPerPeople': 23,
#   'activePerOneMillion': 123.75,
#   'recoveredPerOneMillion': 3886.1,
#   'criticalPerOneMillion': 0.18},
#  {'updated': 1659534616470,
#   'country': 'Falkland Islands (Malvinas)',
# ...
#   'casesPerOneMillion': 16765,
#   'deathsPerOneMillion': 97,
#   'tests': 271855,
#   'testsPerOneMillion': 198333,
#   'population': 1370701,
#   'continent': 'Asia',
#   'oneCasePerPeople': 60,
#   'oneDeathPerPeople': 10306,
#   'oneTestPerPeople': 5,
#   'activePerOneMillion': 8.03,
#   'recoveredPerOneMillion': 16660.09,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534616273,
#   'country': 'Togo',
#   'countryInfo': {'_id': 768,
#    'iso2': 'TG',
#    'iso3': 'TGO',
#    'lat': 8,
#    'long': 1.1667,
#    'flag': 'https://disease.sh/assets/img/flags/tg.png'},
#   'cases': 38104,
#   'todayCases': 0,
#   'deaths': 280,
#   'todayDeaths': 0,
#   'recovered': 37672,
#   'todayRecovered': 0,
#   'active': 152,
#   'critical': 0,
#   'casesPerOneMillion': 4389,
#   'deathsPerOneMillion': 32,
#   'tests': 770446,
#   'testsPerOneMillion': 88736,
#   'population': 8682490,
#   'continent': 'Africa',
#   'oneCasePerPeople': 228,
#   'oneDeathPerPeople': 31009,
#   'oneTestPerPeople': 11,
#   'activePerOneMillion': 17.51,
#   'recoveredPerOneMillion': 4338.85,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534616384,
#   'country': 'Tonga',
#   'countryInfo': {'_id': 776,
#    'iso2': 'TO',
#    'iso3': 'TON',
#    'lat': -20,
#    'long': -175,
#    'flag': 'https://disease.sh/assets/img/flags/to.png'},
#   'cases': 12554,
#   'todayCases': 0,
#   'deaths': 12,
#   'todayDeaths': 0,
#   'recovered': 12423,
#   'todayRecovered': 0,
#   'active': 119,
#   'critical': 0,
#   'casesPerOneMillion': 116039,
#   'deathsPerOneMillion': 111,
#   'tests': 535009,
#   'testsPerOneMillion': 4945179,
#   'population': 108188,
#   'continent': 'Australia-Oceania',
#   'oneCasePerPeople': 9,
#   'oneDeathPerPeople': 9016,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 1099.94,
#   'recoveredPerOneMillion': 114827.89,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534616095,
#   'country': 'Trinidad and Tobago',
#   'countryInfo': {'_id': 780,
#    'iso2': 'TT',
#    'iso3': 'TTO',
#    'lat': 11,
#    'long': -61,
#    'flag': 'https://disease.sh/assets/img/flags/tt.png'},
#   'cases': 171590,
#   'todayCases': 0,
#   'deaths': 4053,
#   'todayDeaths': 0,
#   'recovered': 161098,
#   'todayRecovered': 0,
#   'active': 6439,
#   'critical': 18,
#   'casesPerOneMillion': 121789,
#   'deathsPerOneMillion': 2877,
#   'tests': 793161,
#   'testsPerOneMillion': 562958,
#   'population': 1408916,
#   'continent': 'North America',
#   'oneCasePerPeople': 8,
#   'oneDeathPerPeople': 348,
#   'oneTestPerPeople': 2,
#   'activePerOneMillion': 4570.18,
#   'recoveredPerOneMillion': 114341.81,
#   'criticalPerOneMillion': 12.78},
#  {'updated': 1659534615862,
#   'country': 'Tunisia',
#   'countryInfo': {'_id': 788,
#    'iso2': 'TN',
#    'iso3': 'TUN',
#    'lat': 34,
#    'long': 9,
#    'flag': 'https://disease.sh/assets/img/flags/tn.png'},
#   'cases': 1134660,
#   'todayCases': 0,
#   'deaths': 29105,
#   'todayDeaths': 0,
#   'recovered': 0,
#   'todayRecovered': 0,
#   'active': 1105555,
#   'critical': 29,
#   'casesPerOneMillion': 93960,
#   'deathsPerOneMillion': 2410,
#   'tests': 4863059,
#   'testsPerOneMillion': 402706,
#   'population': 12075950,
#   'continent': 'Africa',
#   'oneCasePerPeople': 11,
#   'oneDeathPerPeople': 415,
#   'oneTestPerPeople': 2,
#   'activePerOneMillion': 91550.15,
#   'recoveredPerOneMillion': 0,
#   'criticalPerOneMillion': 2.4},
#  {'updated': 1659534615664,
#   'country': 'Turkey',
#   'countryInfo': {'_id': 792,
#    'iso2': 'TR',
#    'iso3': 'TUR',
#    'lat': 39,
#    'long': 35,
#    'flag': 'https://disease.sh/assets/img/flags/tr.png'},
#   'cases': 15889495,
#   'todayCases': 0,
#   'deaths': 99341,
#   'todayDeaths': 0,
#   'recovered': 15487468,
#   'todayRecovered': 0,
#   'active': 302686,
#   'critical': 975,
#   'casesPerOneMillion': 184274,
#   'deathsPerOneMillion': 1152,
#   'tests': 162743369,
#   'testsPerOneMillion': 1887372,
#   'population': 86227507,
#   'continent': 'Asia',
#   'oneCasePerPeople': 5,
#   'oneDeathPerPeople': 868,
#   'oneTestPerPeople': 1,
#   'activePerOneMillion': 3510.32,
#   'recoveredPerOneMillion': 179611.69,
#   'criticalPerOneMillion': 11.31},
#  {'updated': 1659534616460,
#   'country': 'Turks and Caicos Islands',
#   'countryInfo': {'_id': 796,
#    'iso2': 'TC',
#    'iso3': 'TCA',
#    'lat': 21.75,
#    'long': -71.5833,
#    'flag': 'https://disease.sh/assets/img/flags/tc.png'},
#   'cases': 6303,
#   'todayCases': 0,
#   'deaths': 36,
#   'todayDeaths': 0,
#   'recovered': 6236,
#   'todayRecovered': 0,
#   'active': 31,
#   'critical': 4,
#   'casesPerOneMillion': 158339,
#   'deathsPerOneMillion': 904,
#   'tests': 548945,
#   'testsPerOneMillion': 13790163,
#   'population': 39807,
#   'continent': 'North America',
#   'oneCasePerPeople': 6,
#   'oneDeathPerPeople': 1106,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 778.76,
#   'recoveredPerOneMillion': 156655.86,
#   'criticalPerOneMillion': 100.48},
#  {'updated': 1659534616478,
#   'country': 'Tuvalu',
#   'countryInfo': {'_id': 798,
#    'iso2': 'TV',
#    'iso3': 'TUV',
#    'lat': -8,
#    'long': 178,
#    'flag': 'https://disease.sh/assets/img/flags/tv.png'},
#   'cases': 8,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 0,
#   'todayRecovered': 0,
#   'active': 8,
#   'critical': 0,
#   'casesPerOneMillion': 661,
#   'deathsPerOneMillion': 0,
#   'tests': 0,
#   'testsPerOneMillion': 0,
#   'population': 12095,
#   'continent': 'Australia-Oceania',
#   'oneCasePerPeople': 1512,
#   'oneDeathPerPeople': 0,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 661.43,
#   'recoveredPerOneMillion': 0,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534615871,
#   'country': 'UAE',
#   'countryInfo': {'_id': 784,
#    'iso2': 'AE',
#    'iso3': 'ARE',
#    'lat': 24,
#    'long': 54,
#    'flag': 'https://disease.sh/assets/img/flags/ae.png'},
#   'cases': 993684,
#   'todayCases': 0,
#   'deaths': 2335,
#   'todayDeaths': 0,
#   'recovered': 972722,
#   'todayRecovered': 0,
#   'active': 18627,
#   'critical': 0,
#   'casesPerOneMillion': 98005,
#   'deathsPerOneMillion': 230,
#   'tests': 177756043,
#   'testsPerOneMillion': 17531800,
#   'population': 10139064,
#   'continent': 'Asia',
#   'oneCasePerPeople': 10,
#   'oneDeathPerPeople': 4342,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 1837.15,
#   'recoveredPerOneMillion': 95938.05,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534615579,
#   'country': 'UK',
#   'countryInfo': {'_id': 826,
#    'iso2': 'GB',
#    'iso3': 'GBR',
#    'lat': 54,
#    'long': -2,
#    'flag': 'https://disease.sh/assets/img/flags/gb.png'},
#   'cases': 23304479,
#   'todayCases': 0,
#   'deaths': 183953,
#   'todayDeaths': 0,
#   'recovered': 22757777,
#   'todayRecovered': 29606,
#   'active': 362749,
#   'critical': 146,
#   'casesPerOneMillion': 339577,
#   'deathsPerOneMillion': 2680,
#   'tests': 522526476,
#   'testsPerOneMillion': 7613901,
#   'population': 68627954,
#   'continent': 'Europe',
#   'oneCasePerPeople': 3,
#   'oneDeathPerPeople': 373,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 5285.73,
#   'recoveredPerOneMillion': 331610.89,
#   'criticalPerOneMillion': 2.13},
#  {'updated': 1659534615572,
#   'country': 'USA',
#   'countryInfo': {'_id': 840,
#    'iso2': 'US',
#    'iso3': 'USA',
#    'lat': 38,
#    'long': -97,
#    'flag': 'https://disease.sh/assets/img/flags/us.png'},
#   'cases': 93319702,
#   'todayCases': 0,
#   'deaths': 1055975,
#   'todayDeaths': 0,
#   'recovered': 88431777,
#   'todayRecovered': 0,
#   'active': 3831950,
#   'critical': 4620,
#   'casesPerOneMillion': 0,
#   'deathsPerOneMillion': 0,
#   'tests': 1069608232,
#   'testsPerOneMillion': 0,
#   'population': 0,
#   'continent': 'North America',
#   'oneCasePerPeople': 0,
#   'oneDeathPerPeople': 0,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 0,
#   'recoveredPerOneMillion': 0,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534616158,
#   'country': 'Uganda',
#   'countryInfo': {'_id': 800,
#    'iso2': 'UG',
#    'iso3': 'UGA',
#    'lat': 1,
#    'long': 32,
#    'flag': 'https://disease.sh/assets/img/flags/ug.png'},
#   'cases': 169340,
#   'todayCases': 0,
#   'deaths': 3628,
#   'todayDeaths': 0,
#   'recovered': 100431,
#   'todayRecovered': 0,
#   'active': 65281,
#   'critical': 3,
#   'casesPerOneMillion': 3474,
#   'deathsPerOneMillion': 74,
#   'tests': 3010848,
#   'testsPerOneMillion': 61765,
#   'population': 48747095,
#   'continent': 'Africa',
#   'oneCasePerPeople': 288,
#   'oneDeathPerPeople': 13436,
#   'oneTestPerPeople': 16,
#   'activePerOneMillion': 1339.18,
#   'recoveredPerOneMillion': 2060.25,
#   'criticalPerOneMillion': 0.06},
#  {'updated': 1659534615680,
#   'country': 'Ukraine',
#   'countryInfo': {'_id': 804,
#    'iso2': 'UA',
#    'iso3': 'UKR',
#    'lat': 49,
#    'long': 32,
#    'flag': 'https://disease.sh/assets/img/flags/ua.png'},
#   'cases': 5023710,
#   'todayCases': 0,
#   'deaths': 108713,
#   'todayDeaths': 0,
#   'recovered': 4911162,
#   'todayRecovered': 150,
#   'active': 3835,
#   'critical': 177,
#   'casesPerOneMillion': 116323,
#   'deathsPerOneMillion': 2517,
#   'tests': 19521252,
#   'testsPerOneMillion': 452012,
#   'population': 43187425,
#   'continent': 'Europe',
#   'oneCasePerPeople': 9,
#   'oneDeathPerPeople': 397,
#   'oneTestPerPeople': 2,
#   'activePerOneMillion': 88.8,
#   'recoveredPerOneMillion': 113717.41,
#   'criticalPerOneMillion': 4.1},
#  {'updated': 1659534615959,
#   'country': 'Uruguay',
#   'countryInfo': {'_id': 858,
#    'iso2': 'UY',
#    'iso3': 'URY',
#    'lat': -33,
#    'long': -56,
#    'flag': 'https://disease.sh/assets/img/flags/uy.png'},
#   'cases': 971728,
#   'todayCases': 0,
#   'deaths': 7415,
#   'todayDeaths': 0,
#   'recovered': 962545,
#   'todayRecovered': 0,
#   'active': 1768,
#   'critical': 18,
#   'casesPerOneMillion': 277734,
#   'deathsPerOneMillion': 2119,
#   'tests': 6114822,
#   'testsPerOneMillion': 1747704,
#   'population': 3498775,
#   'continent': 'South America',
#   'oneCasePerPeople': 4,
#   'oneDeathPerPeople': 472,
#   'oneTestPerPeople': 1,
#   'activePerOneMillion': 505.32,
#   'recoveredPerOneMillion': 275109.15,
#   'criticalPerOneMillion': 5.14},
#  {'updated': 1659534616085,
#   'country': 'Uzbekistan',
#   'countryInfo': {'_id': 860,
#    'iso2': 'UZ',
#    'iso3': 'UZB',
#    'lat': 41,
#    'long': 64,
#    'flag': 'https://disease.sh/assets/img/flags/uz.png'},
#   'cases': 243195,
#   'todayCases': 33,
#   'deaths': 1637,
#   'todayDeaths': 0,
#   'recovered': 240420,
#   'todayRecovered': 54,
#   'active': 1138,
#   'critical': 23,
#   'casesPerOneMillion': 7054,
#   'deathsPerOneMillion': 47,
#   'tests': 1377915,
#   'testsPerOneMillion': 39964,
#   'population': 34478582,
#   'continent': 'Asia',
#   'oneCasePerPeople': 142,
#   'oneDeathPerPeople': 21062,
#   'oneTestPerPeople': 25,
#   'activePerOneMillion': 33.01,
#   'recoveredPerOneMillion': 6973.02,
#   'criticalPerOneMillion': 0.67},
#  {'updated': 1659534616389,
#   'country': 'Vanuatu',
#   'countryInfo': {'_id': 548,
#    'iso2': 'VU',
#    'iso3': 'VUT',
#    'lat': -16,
#    'long': 167,
#    'flag': 'https://disease.sh/assets/img/flags/vu.png'},
#   'cases': 11723,
#   'todayCases': 0,
#   'deaths': 14,
#   'todayDeaths': 0,
#   'recovered': 11672,
#   'todayRecovered': 0,
#   'active': 37,
#   'critical': 0,
#   'casesPerOneMillion': 36398,
#   'deathsPerOneMillion': 43,
#   'tests': 24976,
#   'testsPerOneMillion': 77546,
#   'population': 322081,
#   'continent': 'Australia-Oceania',
#   'oneCasePerPeople': 27,
#   'oneDeathPerPeople': 23006,
#   'oneTestPerPeople': 13,
#   'activePerOneMillion': 114.88,
#   'recoveredPerOneMillion': 36239.33,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534616066,
#   'country': 'Venezuela',
#   'countryInfo': {'_id': 862,
#    'iso2': 'VE',
#    'iso3': 'VEN',
#    'lat': 8,
#    'long': -66,
#    'flag': 'https://disease.sh/assets/img/flags/ve.png'},
#   'cases': 536586,
#   'todayCases': 0,
#   'deaths': 5763,
#   'todayDeaths': 0,
#   'recovered': 525725,
#   'todayRecovered': 0,
#   'active': 5098,
#   'critical': 36,
#   'casesPerOneMillion': 18982,
#   'deathsPerOneMillion': 204,
#   'tests': 3359014,
#   'testsPerOneMillion': 118826,
#   'population': 28268374,
#   'continent': 'South America',
#   'oneCasePerPeople': 53,
#   'oneDeathPerPeople': 4905,
#   'oneTestPerPeople': 8,
#   'activePerOneMillion': 180.34,
#   'recoveredPerOneMillion': 18597.64,
#   'criticalPerOneMillion': 1.27},
#  {'updated': 1659534615669,
#   'country': 'Vietnam',
#   'countryInfo': {'_id': 704,
#    'iso2': 'VN',
#    'iso3': 'VNM',
#    'lat': 21,
#    'long': 105.8,
#    'flag': 'https://disease.sh/assets/img/flags/vn.png'},
#   'cases': 10785122,
#   'todayCases': 2096,
#   'deaths': 43094,
#   'todayDeaths': 0,
#   'recovered': 9940462,
#   'todayRecovered': 7750,
#   'active': 801566,
#   'critical': 80,
#   'casesPerOneMillion': 108764,
#   'deathsPerOneMillion': 435,
#   'tests': 85826548,
#   'testsPerOneMillion': 865528,
#   'population': 99160960,
#   'continent': 'Asia',
#   'oneCasePerPeople': 9,
#   'oneDeathPerPeople': 2301,
#   'oneTestPerPeople': 1,
#   'activePerOneMillion': 8083.48,
#   'recoveredPerOneMillion': 100245.72,
#   'criticalPerOneMillion': 0.81},
#  {'updated': 1659534616472,
#   'country': 'Wallis and Futuna',
#   'countryInfo': {'_id': 876,
#    'iso2': 'WF',
#    'iso3': 'WLF',
#    'lat': -13.3,
#    'long': -176.2,
#    'flag': 'https://disease.sh/assets/img/flags/wf.png'},
#   'cases': 761,
#   'todayCases': 0,
#   'deaths': 7,
#   'todayDeaths': 0,
#   'recovered': 438,
#   'todayRecovered': 0,
#   'active': 316,
#   'critical': 0,
#   'casesPerOneMillion': 70268,
#   'deathsPerOneMillion': 646,
#   'tests': 20508,
#   'testsPerOneMillion': 1893629,
#   'population': 10830,
#   'continent': 'Australia-Oceania',
#   'oneCasePerPeople': 14,
#   'oneDeathPerPeople': 1547,
#   'oneTestPerPeople': 1,
#   'activePerOneMillion': 29178.21,
#   'recoveredPerOneMillion': 40443.21,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534616476,
#   'country': 'Western Sahara',
#   'countryInfo': {'_id': 732,
#    'iso2': 'EH',
#    'iso3': 'ESH',
#    'lat': 24.5,
#    'long': -13,
#    'flag': 'https://disease.sh/assets/img/flags/eh.png'},
#   'cases': 10,
#   'todayCases': 0,
#   'deaths': 1,
#   'todayDeaths': 0,
#   'recovered': 9,
#   'todayRecovered': 0,
#   'active': 0,
#   'critical': 0,
#   'casesPerOneMillion': 16,
#   'deathsPerOneMillion': 2,
#   'tests': 0,
#   'testsPerOneMillion': 0,
#   'population': 627901,
#   'continent': 'Africa',
#   'oneCasePerPeople': 62790,
#   'oneDeathPerPeople': 627901,
#   'oneTestPerPeople': 0,
#   'activePerOneMillion': 0,
#   'recoveredPerOneMillion': 14.33,
#   'criticalPerOneMillion': 0},
#  {'updated': 1659534616388,
#   'country': 'Yemen',
#   'countryInfo': {'_id': 887,
#    'iso2': 'YE',
#    'iso3': 'YEM',
#    'lat': 15,
#    'long': 48,
#    'flag': 'https://disease.sh/assets/img/flags/ye.png'},
#   'cases': 11877,
#   'todayCases': 0,
#   'deaths': 2151,
#   'todayDeaths': 0,
#   'recovered': 9117,
#   'todayRecovered': 0,
#   'active': 609,
#   'critical': 23,
#   'casesPerOneMillion': 381,
#   'deathsPerOneMillion': 69,
#   'tests': 265253,
#   'testsPerOneMillion': 8504,
#   'population': 31192930,
#   'continent': 'Asia',
#   'oneCasePerPeople': 2626,
#   'oneDeathPerPeople': 14502,
#   'oneTestPerPeople': 118,
#   'activePerOneMillion': 19.52,
#   'recoveredPerOneMillion': 292.28,
#   'criticalPerOneMillion': 0.74},
#  {'updated': 1659534616077,
#   'country': 'Zambia',
#   'countryInfo': {'_id': 894,
#    'iso2': 'ZM',
#    'iso3': 'ZMB',
#    'lat': -15,
#    'long': 30,
#    'flag': 'https://disease.sh/assets/img/flags/zm.png'},
#   'cases': 330575,
#   'todayCases': 0,
#   'deaths': 4015,
#   'todayDeaths': 0,
#   'recovered': 325321,
#   'todayRecovered': 0,
#   'active': 1239,
#   'critical': 1,
#   'casesPerOneMillion': 16991,
#   'deathsPerOneMillion': 206,
#   'tests': 3642327,
#   'testsPerOneMillion': 187215,
#   'population': 19455353,
#   'continent': 'Africa',
#   'oneCasePerPeople': 59,
#   'oneDeathPerPeople': 4846,
#   'oneTestPerPeople': 5,
#   'activePerOneMillion': 63.68,
#   'recoveredPerOneMillion': 16721.41,
#   'criticalPerOneMillion': 0.05},
#  {'updated': 1659534616084,
#   'country': 'Zimbabwe',
#   'countryInfo': {'_id': 716,
#    'iso2': 'ZW',
#    'iso3': 'ZWE',
#    'lat': -20,
#    'long': 30,
#    'flag': 'https://disease.sh/assets/img/flags/zw.png'},
#   'cases': 256403,
#   'todayCases': 0,
#   'deaths': 5578,
#   'todayDeaths': 0,
#   'recovered': 250368,
#   'todayRecovered': 0,
#   'active': 457,
#   'critical': 12,
#   'casesPerOneMillion': 16744,
#   'deathsPerOneMillion': 364,
#   'tests': 2451783,
#   'testsPerOneMillion': 160110,
#   'population': 15313161,
#   'continent': 'Africa',
#   'oneCasePerPeople': 60,
#   'oneDeathPerPeople': 2745,
#   'oneTestPerPeople': 6,
#   'activePerOneMillion': 29.84,
#   'recoveredPerOneMillion': 16349.86,
#   'criticalPerOneMillion': 0.78}]

# %%
dataframe= pd.DataFrame(json_data)
dataframe.tail()
# Out:
#            updated            country  \
# 225  1659534616472  Wallis and Futuna
# 226  1659534616476     Western Sahara
# 227  1659534616388              Yemen
# 228  1659534616077             Zambia
# 229  1659534616084           Zimbabwe
#
#                                            countryInfo   cases  todayCases  \
# 225  {'_id': 876, 'iso2': 'WF', 'iso3': 'WLF', 'lat...     761           0
# 226  {'_id': 732, 'iso2': 'EH', 'iso3': 'ESH', 'lat...      10           0
# 227  {'_id': 887, 'iso2': 'YE', 'iso3': 'YEM', 'lat...   11877           0
# 228  {'_id': 894, 'iso2': 'ZM', 'iso3': 'ZMB', 'lat...  330575           0
# 229  {'_id': 716, 'iso2': 'ZW', 'iso3': 'ZWE', 'lat...  256403           0
#
#      deaths  todayDeaths  recovered  todayRecovered  active  ...    tests  \
# 225       7            0        438               0     316  ...    20508
# 226       1            0          9               0       0  ...        0
# 227    2151            0       9117               0     609  ...   265253
# 228    4015            0     325321               0    1239  ...  3642327
# 229    5578            0     250368               0     457  ...  2451783
#
#      testsPerOneMillion  population          continent  oneCasePerPeople  \
# 225             1893629       10830  Australia-Oceania                14
# 226                   0      627901             Africa             62790
# 227                8504    31192930               Asia              2626
# 228              187215    19455353             Africa                59
# 229              160110    15313161             Africa                60
#
#      oneDeathPerPeople oneTestPerPeople  activePerOneMillion  \
# 225               1547                1             29178.21
# 226             627901                0                 0.00
# 227              14502              118                19.52
# 228               4846                5                63.68
# 229               2745                6                29.84
#
#      recoveredPerOneMillion  criticalPerOneMillion
# 225                40443.21                   0.00
# 226                   14.33                   0.00
# 227                  292.28                   0.74
# 228                16721.41                   0.05
# 229                16349.86                   0.78
#
# [5 rows x 23 columns]
